# %% [markdown]
# ## Conditional_Statement Defination

# %% [markdown]
# Defination:
# Conditional statements are used to make decisions in a program.They execute different blocks of code based on whether a condition is True or False.
# Types of conditional statements:
#    1.if
#    2.if-else(else)
#    3.if-elif-else
#    4.Nested if

# %%
Game:

1) fix the word in my mind
2) ask the word 
3)collect answer
4)checking/matching the answer with my answer
5)Announce "word matched" or "not matched"

# %%
my_word="Tubelight" 
student=eval(input('give your word')) 
my_word==student
# Out:
# give your word "likitha"
# False

# %%
my_word="Tubelight" 
student=eval(input('give your word')) 
my_word==student
print('w matched')
# Out:
# give your word "Tubelight"
# w matched

# %%
#conditional statement:if
my_word="Tubelight" 
student=eval(input('give your word')) 
if my_word==student :  #spacing is called indentation
     print('word matched')
     print('this is a line in if')
     print('new line in if') 
print('thank you')

#consistent spacing is important 
#while creating the body of a conditional statement
# Out:
# give your word "Tubelight"
# word matched
# this is a line in if
# new line in if
# thank you

# %%
a=10
if a:
    print('this is in if')
print('new stat')
# Out:
# this is in if
# new stat

# %%
a=''
if a:
    print('this is in if')
print('new stat')
# Out:
# new stat

# %%
#check if someone is eligible to vote
a=int(input('give your age') )
if a>=18:
    print('eligible')  
if a<18:
    print('not eligible')  

print('thank you')
# Out:
# give your age 25
# eligible
# thank you

# %%
#Vowels in given word 
word='ae'
vowels=['a','e','i','o','u']
if word[0] in vowels or word[1] in vowels: 
    print('vowels present')
# Out:
# vowels present

# %%
a='90'
b=['67',90] 
#b in a #cannot iterate over a 
#b in a #cannot search list in a string
#a in b #a is the thing you are searching and b is the place 
a in b
# Out:
# False

# %%
#if else 
a=90
if a==90 :
    print('yes') 
else:  #cannot exist without if, does not have any condition to validate
    print('no')

# %%
1)ask the user name and age
2) check if the age is greater than or equal to 21
if yes,then print 'welcome to club' else 'not welcome;

# %%
name=input()
age=int(input())
if age>=21:
    print("Welcome to club")
else:
    print("Not welcome")
# Out:
#  Likitha
#  4
# Not welcome

# %%
#even odd
a=int(input())
if a%2==0:
    print("Even")
else:
    print("odd")
# Out:
#  10
# Even

# %%
#check if the age is more than 21 and if so then check if their name starts with 'Y'
if yes then print "you won lottery",else "did not win"

# %%
name=input()
age=int(input())
if age>21 and name.startswith("Y"):
    print("you won lottery")
else:
    print("did not win")
# Out:
#  Yellow
#  23
# you won lottery

# %%
#if someone is age 21 -45 ---then enter club 1
if their age is 45--70---club 2
if more than 70---no club

# %%
age=int(input())
if age>0 and age<=100:
    if age>=21 and  age<45:
        print("welcome club 1")
    elif age>=45 and age<70:
        print("club2")
    else:
        print("club3")
else:
    print("age is out of boundery")
# Out:
#  -1
# age is out of boundery

# %%
30-50: D
50-70:c

70-80:b
80-90:a
90-100:a1

# %%
marks=int(input())
if marks>0 and marks<=100:
    if marks>90 and marks<=100:
        print("a1")
    elif marks>80 and marks<=90:
        print("a")
    elif marks>70 and marks<=80:
        print("b")
    elif marks<70 and marks>=50:
        print("c")
    else:
        print("Fail")
else:
    print("Please entire valid marks")
# Out:
#  899
# Please entire valid marks

# %%
#Tringle 
a = int(input())
b = int(input())
c = int(input())

if a == b and b == c:
    print("Equilateral")
elif a == b or b == c or a == c:
    print("Isosceles")
else:
    print("Scalene")
# Out:
#  2
#  3
#  4
# Scalene

# %%
#Caluculate Body mass index
Severe Thinness	< 16
Mild Thinness	17 - 18.5
Normal	18.5 - 25
Overweight	25 - 30
Obese Class I	30 - 40
Obese Class II> 40

BMI=weight/height

# %%
w=int(input())
h=float(input())
BMI=w/(h**2)
if BMI<16:
    print("Severe Thinness")
elif BMI>=16 and BMI<18.5:
    print("Mild Thinness")
elif BMI>=18.5 and BMI<25:
    print("Overweight")
elif BMI>=25 and BMI<30:
    Print("Obese Class I")
elif BMI>=30 and BMI<=40:
    print("Obese Class II")
else:
    print("your Obese person")
# Out:
#  60
#  1.65
# Overweight
